# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexandersalzar67/UIII-Act-10-youtuber-Proyecto-de-simulaci-n-de-inteligencia-artificial-/blob/main/UIII_Act_10_Proyecto_de_simulaci%C3%B3n_de_inteligencia_artificial_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Alexander Salazar NL = 53 Mayo/25/2026
# ## youtuber
# ![texto del vínculo](https://raw.githubusercontent.com/Alexandersalzar67/UIII-Act-10-youtuber-Proyecto-de-simulaci-n-de-inteligencia-artificial-/refs/heads/main/1a878c43-d4cd-4870-84c5-403615dd0530.png)

# %%
# ==============================================
# IA DE YOUTUBERS
# Uso de:
# - Lista de diccionarios
# - if
# - elif
# - else
# - while True
# - for
# ==============================================

print("==========================================")
print("      IA DE YOUTUBERS VIRTUALES")
print("       CBTIS 128 - Programacion")
print("==========================================")

# Lista vacia
youtubers = []

# Diccionario vacio
youtuber = {}

while True:

    print("\n=========== MENU ===========")
    print("1. Registrar youtuber")
    print("2. Ver youtubers")
    print("3. Analizar canal")
    print("4. Eliminar ultimo youtuber")
    print("5. Salir")
    print("============================")

    opcion = int(input("Selecciona una opcion: "))

    # OPCION 1
    if opcion == 1:

        nombre = input("Nombre del youtuber: ")
        categoria = input("Categoria del canal: ")
        seguidores = int(input("Numero de seguidores: "))

        # Diccionario
        youtuber = {
            "nombre": nombre,
            "categoria": categoria,
            "seguidores": seguidores
        }

        # Guardar en la lista
        youtubers.append(youtuber)

        print("Youtuber registrado correctamente")

    # OPCION 2
    elif opcion == 2:

        if youtubers == []:
            print("No hay youtubers registrados")

        else:

            print("\n+------------------------------------------------------+")
            print("| ID | NOMBRE | CATEGORIA | SEGUIDORES               |")
            print("+------------------------------------------------------+")

            contador = 1

            for datos in youtubers:

                print("|", contador,
                      "|", datos["nombre"],
                      "|", datos["categoria"],
                      "|", datos["seguidores"])

                contador = contador + 1

            print("+------------------------------------------------------+")

    # OPCION 3
    elif opcion == 3:

        cantidad = len(youtubers)

        print("\n=========== ANALISIS IA ===========")

        if cantidad == 0:
            print("No existen canales registrados")
            print("La IA recomienda agregar youtubers")

        elif cantidad >= 1 and cantidad <= 3:
            print("Pocos youtubers registrados")
            print("La IA detecta canales principiantes")

        elif cantidad >= 4 and cantidad <= 6:
            print("Comunidad en crecimiento")
            print("La IA detecta potencial viral")

        else:
            print("Muchos youtubers registrados")
            print("La IA detecta futuros influencers")

    # OPCION 4
    elif opcion == 4:

        if youtubers == []:
            print("No hay youtubers para eliminar")

        else:

            eliminado = youtubers.pop()

            print("Youtuber eliminado:", eliminado["nombre"])

    # OPCION 5
    elif opcion == 5:

        print("Cerrando sistema de IA...")
        print("Hasta luego")
        break

    # OPCION INVALIDA
    else:

        print("Opcion incorrecta")
# Out:
# ==========================================
#       IA DE YOUTUBERS VIRTUALES
#        CBTIS 128 - Programacion
# ==========================================
#
# =========== MENU ===========
# 1. Registrar youtuber
# 2. Ver youtubers
# 3. Analizar canal
# 4. Eliminar ultimo youtuber
# 5. Salir
# ============================
# Selecciona una opcion: 1
# Nombre del youtuber: javier124
# Categoria del canal: videojuegos
# Numero de seguidores: 25678
# Youtuber registrado correctamente
#
# =========== MENU ===========
# 1. Registrar youtuber
# 2. Ver youtubers
# 3. Analizar canal
# 4. Eliminar ultimo youtuber
# 5. Salir
# ============================
# Selecciona una opcion: 2
#
# +------------------------------------------------------+
# | ID | NOMBRE | CATEGORIA | SEGUIDORES               |
# +------------------------------------------------------+
# | 1 | javier124 | videojuegos | 25678
# +------------------------------------------------------+
#
# =========== MENU ===========
# 1. Registrar youtuber
# 2. Ver youtubers
# 3. Analizar canal
# 4. Eliminar ultimo youtuber
# 5. Salir
# ============================
# Selecciona una opcion: 1
# Nombre del youtuber: alex234
# Categoria del canal: vlogs
# Numero de seguidores: 246567
# Youtuber registrado correctamente
#
# =========== MENU ===========
# 1. Registrar youtuber
# 2. Ver youtubers
# 3. Analizar canal
# 4. Eliminar ultimo youtuber
# 5. Salir
# ============================
# Selecciona una opcion: 2
#
# +------------------------------------------------------+
# | ID | NOMBRE | CATEGORIA | SEGUIDORES               |
# +------------------------------------------------------+
# | 1 | javier124 | videojuegos | 25678
# | 2 | alex234 | vlogs | 246567
# +------------------------------------------------------+
#
# =========== MENU ===========
# 1. Registrar youtuber
# 2. Ver youtubers
# 3. Analizar canal
# 4. Eliminar ultimo youtuber
# 5. Salir
# ============================
# Selecciona una opcion: 1
# Nombre del youtuber: juan585
# Categoria del canal: comedias
# Numero de seguidores: 24563
# Youtuber registrado correctamente
#
# =========== MENU ===========
# 1. Registrar youtuber
# 2. Ver youtubers
# 3. Analizar canal
# 4. Eliminar ultimo youtuber
# 5. Salir
# ============================
# Selecciona una opcion: 2
#
# +------------------------------------------------------+
# | ID | NOMBRE | CATEGORIA | SEGUIDORES               |
# +------------------------------------------------------+
# | 1 | javier124 | videojuegos | 25678
# | 2 | alex234 | vlogs | 246567
# | 3 | juan585 | comedias | 24563
# +------------------------------------------------------+
#
# =========== MENU ===========
# 1. Registrar youtuber
# 2. Ver youtubers
# 3. Analizar canal
# 4. Eliminar ultimo youtuber
# 5. Salir
# ============================
# Selecciona una opcion: 3
#
# =========== ANALISIS IA ===========
# Pocos youtubers registrados
# La IA detecta canales principiantes
#
# =========== MENU ===========
# 1. Registrar youtuber
# 2. Ver youtubers
# 3. Analizar canal
# 4. Eliminar ultimo youtuber
# 5. Salir
# ============================
# Selecciona una opcion: 4
# Youtuber eliminado: juan585
#
# =========== MENU ===========
# 1. Registrar youtuber
# 2. Ver youtubers
# 3. Analizar canal
# 4. Eliminar ultimo youtuber
# 5. Salir
# ============================
# Selecciona una opcion: 2
#
# +------------------------------------------------------+
# | ID | NOMBRE | CATEGORIA | SEGUIDORES               |
# +------------------------------------------------------+
# | 1 | javier124 | videojuegos | 25678
# | 2 | alex234 | vlogs | 246567
# +------------------------------------------------------+
#
# =========== MENU ===========
# 1. Registrar youtuber
# 2. Ver youtubers
# 3. Analizar canal
# 4. Eliminar ultimo youtuber
# 5. Salir
# ============================
# Selecciona una opcion: 5
# Cerrando sistema de IA...
# Hasta luego
